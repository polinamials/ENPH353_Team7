# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random
from random import randint
from PIL import Image, ImageFont, ImageDraw
import string

# %%
plate_syms = np.load('/home/fizzer/ros_ws/src/controller_pkg/cnn_trainer/data/plate_symbols.npy', allow_pickle=True)

# %%
for plate in plate_syms:
    for s in plate:
        plt.imshow(s, cmap='gray')
        plt.show()

# %%
from skimage.util import random_noise
from skimage.io import imsave
from skimage.transform import resize

# %%
def generate_noisy_symbol(sym):
    img = cv2.imread('/home/fizzer/ros_ws/src/2022_competition/enph353/enph353_gazebo/scripts/blank_plate.png')
    img=img[50:350,:]
    img = img[100:250, 5:105]

    rows=150
    cols=100
    font_size = 200
    
    OVERLAY = random.randint(-100,0)
    TB=random.randint(70,220)
    TG=random.randint(0,50)
    TR=random.randint(0,50)
    
    TX=random.randint(-1,1)
    TY=random.randint(-31,-29)
    
    CENTER=(random.randint(24,26),random.randint(24,26))
    AXES=(random.randint(0,10),0)
    ANGLE = random.randint(0,360)
    
    GKERNEL = random.randint(5,25)
    if GKERNEL%2==0:
        GKERNEL+=1
    
    sym=str(sym)
    
    
    if sym=='Q':
        font_size=175

    overlay=np.full((rows,cols,3), OVERLAY)
    img=np.clip(img+overlay,0,255).astype('uint8')


    img_pil = Image.fromarray(img)

    draw = ImageDraw.Draw(img_pil)
    monospace = ImageFont.truetype("/usr/share/fonts/truetype/ubuntu/UbuntuMono-R.ttf", font_size)

    draw.text((TX, TY),sym, (TB,TG,TR), font=monospace)
    #draw.text((0, -30),sym, (255,0,0), font=monospace)

    img = np.array(img_pil)


    noise = np.zeros((rows//2,cols//2,3))
    noise = random_noise(noise,mode='gaussian',var=12312321)
    noise = resize(noise, (rows, cols))
    img=np.clip(img+(img*noise),0,255).astype('uint8')


    # randomize all these numbers for motion blur
    psf = np.zeros((50, 50, 3))
    psf = cv2.ellipse(psf, 
                  CENTER, # center
                  AXES, # axes -- 22 for blur length, 0 for thin PSF 
                  ANGLE, # angle of motion in degrees
                  0, 360, # ful ellipse, not an arc
                  (1, 1, 1), # white color
                  thickness=-1) # filled

    psf /= psf[:,:,0].sum() # normalize by sum of one channel 
                            # since channels are processed independently

    img = cv2.filter2D(img, -1, psf)

    # vary gaussian blur slightly
    img=cv2.GaussianBlur(img, (GKERNEL,GKERNEL),0)


    img=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    return img

# %%
def generate_data(num):
    letters = list(string.ascii_uppercase)
    imgs = []
    labels=[]
    NUM=num
    for l in letters:
        print('starting letter ',l, end='\r')
        for i in range(NUM):
            imgs.append(generate_noisy_symbol(l))
            labels.append(l)
            
            if i%10==0:
                print(i, end='\r')
        print('finished letter ',l, end='\r')
            
    for d in range(10):
        print('starting digit ',d, end='\r')
        for i in range(NUM):
            imgs.append(generate_noisy_symbol(d))
            labels.append(d)
            if i%10==0:
                print(i, end='\r')
        print('finished digit ',d, end='\r')
            
    return imgs, labels

# %%
NUM=500
imgs, labels = generate_data(NUM)
# Out:
# starting letter  A
# finished letter  A
# starting letter  B
# finished letter  B
# starting letter  C
# finished letter  C
# starting letter  D
# finished letter  D
# starting letter  E
# finished letter  E
# starting letter  F
# finished letter  F
# starting letter  G
# finished letter  G
# starting letter  H
# finished letter  H
# starting letter  I
# finished letter  I
# starting letter  J
# finished letter  J
# starting letter  K
# finished letter  K
# starting letter  L
# finished letter  L
# starting letter  M
# finished letter  M
# starting letter  N
# finished letter  N
# starting letter  O
# finished letter  O
# starting letter  P
# finished letter  P
# starting letter  Q
# finished letter  Q
# starting letter  R
# finished letter  R
# starting letter  S
# finished letter  S
# starting letter  T
# finished letter  T
# starting letter  U
# finished letter  U
# starting letter  V
# finished letter  V
# starting letter  W
# finished letter  W
# starting letter  X
# finished letter  X
# starting letter  Y
# finished letter  Y
# starting letter  Z
# finished letter  Z
# starting digit  0
# finished digit  0
# starting digit  1
# finished digit  1
# starting digit  2
# finished digit  2
# starting digit  3
# finished digit  3
# starting digit  4
# finished digit  4
# starting digit  5
# finished digit  5
# starting digit  6
# finished digit  6
# starting digit  7
# finished digit  7
# starting digit  8
# finished digit  8
# starting digit  9
# finished digit  9

# %%
plt.imshow(imgs[1080], cmap='gray')

# %%
np.save('/home/fizzer/ros_ws/src/controller_pkg/cnn_trainer/plates/imgs1.npy',imgs)

# %%
np.save('/home/fizzer/ros_ws/src/controller_pkg/cnn_trainer/plates/labels1.npy',labels)
